# %%
 #Importing pandas library
import pandas as pd
#Loading data into a DataFrame
data_frame=pd.read_csv('/content/drive/MyDrive/SDGP Implementation/data.csv')

# %%
#displaying first five rows
data_frame.head()
# Out:
#           Income  Age  Dependents     Occupation City_Tier          Rent  \
# 0   44637.249636   49           0  Self_Employed    Tier_1  13391.174891
# 1   26858.596592   34           2        Retired    Tier_2   5371.719318
# 2   50367.605084   35           1        Student    Tier_3   7555.140763
# 3  101455.600247   21           0  Self_Employed    Tier_3  15218.340037
# 4   24875.283548   52           4   Professional    Tier_2   4975.056710
#
#    Loan_Repayment    Insurance     Groceries    Transport  ...  \
# 0        0.000000  2206.490129   6658.768341  2636.970696  ...
# 1        0.000000   869.522617   2818.444460  1543.018778  ...
# 2     4612.103386  2201.800050   6313.222081  3221.396403  ...
# 3     6809.441427  4889.418087  14690.149363  7106.130005  ...
# 4     3112.609398   635.907170   3034.329665  1276.155163  ...
#
#    Desired_Savings  Disposable_Income  Potential_Savings_Groceries  \
# 0      6200.537192       11265.627707                  1685.696222
# ...

# %%
# Program to print all the column names of the data_frame
list(data_frame.columns)
# Out:
# ['Income',
#  'Age',
#  'Dependents',
#  'Occupation',
#  'City_Tier',
#  'Rent',
#  'Loan_Repayment',
#  'Insurance',
#  'Groceries',
#  'Transport',
#  'Eating_Out',
#  'Entertainment',
#  'Utilities',
#  'Healthcare',
#  'Education',
#  'Miscellaneous',
#  'Desired_Savings_Percentage',
#  'Desired_Savings',
#  'Disposable_Income',
#  'Potential_Savings_Groceries',
#  'Potential_Savings_Transport',
#  'Potential_Savings_Eating_Out',
#  'Potential_Savings_Entertainment',
#  'Potential_Savings_Utilities',
#  'Potential_Savings_Healthcare',
#  'Potential_Savings_Education',
#  'Potential_Savings_Miscellaneous']

# %%
data_frame.describe()
# Out:
#              Income           Age    Dependents           Rent  \
# count  2.000000e+04  20000.000000  20000.000000   20000.000000
# mean   4.158550e+04     41.031450      1.995950    9115.494629
# std    4.001454e+04     13.578725      1.417616    9254.228188
# min    1.301187e+03     18.000000      0.000000     235.365692
# 25%    1.760488e+04     29.000000      1.000000    3649.422246
# 50%    3.018538e+04     41.000000      2.000000    6402.751824
# 75%    5.176545e+04     53.000000      3.000000   11263.940492
# max    1.079728e+06     64.000000      4.000000  215945.674703
#
#        Loan_Repayment     Insurance      Groceries     Transport  \
# count    20000.000000  20000.000000   20000.000000  20000.000000
# mean      2049.800292   1455.028761    5205.667493   2704.466685
# std       4281.789941   1492.938435    5035.953689   2666.345648
# min          0.000000     30.002012     154.078240     81.228584
# 25%          0.000000    580.204749    2165.426419   1124.578012
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Income                           20000 non-null  float64
#  1   Age                              20000 non-null  int64
#  2   Dependents                       20000 non-null  int64
#  3   Occupation                       20000 non-null  object
#  4   City_Tier                        20000 non-null  object
#  5   Rent                             20000 non-null  float64
#  6   Loan_Repayment                   20000 non-null  float64
#  7   Insurance                        20000 non-null  float64
#  8   Groceries                        20000 non-null  float64
#  9   Transport                        20000 non-null  float64
#  10  Eating_Out                       20000 non-null  float64
# ...

# %%
data_frame.describe(include='object')
# Out:
#        Occupation City_Tier
# count       20000     20000
# unique          4         3
# top       Retired    Tier_2
# freq         5019     10068

# %%
data_frame.shape
# Out:
# (20000, 27)

# %%
data_frame.isnull().sum()
# Out:
# Income                             0
# Age                                0
# Dependents                         0
# Occupation                         0
# City_Tier                          0
# Rent                               0
# Loan_Repayment                     0
# Insurance                          0
# Groceries                          0
# Transport                          0
# Eating_Out                         0
# Entertainment                      0
# Utilities                          0
# Healthcare                         0
# Education                          0
# Miscellaneous                      0
# Desired_Savings_Percentage         0
# Desired_Savings                    0
# Disposable_Income                  0
# Potential_Savings_Groceries        0
# Potential_Savings_Transport        0
# Potential_Savings_Eating_Out       0
# Potential_Savings_Entertainment    0
# Potential_Savings_Utilities        0
# Potential_Savings_Healthcare       0
# ...

# %%
data_frame[['Income']].describe()
# Out:
#              Income
# count  2.000000e+04
# mean   4.158550e+04
# std    4.001454e+04
# min    1.301187e+03
# 25%    1.760488e+04
# 50%    3.018538e+04
# 75%    5.176545e+04
# max    1.079728e+06

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_frame[['Age']].describe()
# Out:
#                 Age
# count  20000.000000
# mean      41.031450
# std       13.578725
# min       18.000000
# 25%       29.000000
# 50%       41.000000
# 75%       53.000000
# max       64.000000

# %%
data_frame[['Age']].describe()
# Out:
#                 Age
# count  20000.000000
# mean      41.031450
# std       13.578725
# min       18.000000
# 25%       29.000000
# 50%       41.000000
# 75%       53.000000
# max       64.000000

# %%
data_frame[['Age']].value_counts(normalize=True)
# Out:
# Age
# 47     0.02405
# 46     0.02305
# 21     0.02300
# 34     0.02245
# 43     0.02240
# 44     0.02240
# 40     0.02220
# 55     0.02215
# 56     0.02205
# 59     0.02205
# 58     0.02200
# 22     0.02200
# 61     0.02200
# 57     0.02195
# 19     0.02190
# 37     0.02185
# 39     0.02180
# 45     0.02175
# 53     0.02155
# 23     0.02150
# 41     0.02150
# 27     0.02140
# 24     0.02140
# 64     0.02135
# 35     0.02120
# 51     0.02120
# 25     0.02120
# 38     0.02120
# 28     0.02105
# 18     0.02100
# 63     0.02095
# 62     0.02095
# 33     0.02070
# 20     0.02070
# 49     0.02065
# 60     0.02065
# 30     0.02040
# 31     0.02030
# 26     0.02025
# 29     0.02020
# 52     0.02020
# 42     0.02015
# 48     0.02000
# 36     0.01950
# 32     0.01945
# 50     0.01935
# 54     0.01900
# Name: proportion, dtype: float64

# %%
data_frame.groupby('Age')[['Income']].mean().sort_values(by='Age')
# Out:
#            Income
# Age
# 18   42693.958699
# 19   41119.464152
# 20   41138.458234
# 21   42093.026955
# 22   42292.638448
# 23   43929.269124
# 24   43339.961352
# 25   40433.637275
# 26   41423.269375
# 27   40031.678842
# 28   40481.137124
# 29   44014.925164
# 30   39057.861676
# 31   42182.054031
# 32   40846.693940
# 33   44528.858202
# 34   38843.768895
# 35   43417.264831
# 36   41694.219379
# 37   39864.216759
# 38   40865.678253
# 39   42989.970280
# 40   43346.301386
# 41   41219.050511
# 42   40225.185873
# 43   41643.692710
# 44   39407.815162
# 45   39691.743501
# 46   43946.369293
# 47   44348.726011
# 48   41146.135002
# 49   43335.422431
# 50   42468.562003
# 51   40052.275891
# 52   42125.227164
# 53   41040.146373
# 54   40154.068359
# 55   42638.621513
# 56   40272.148819
# 57   42558.509818
# 58   40199.338098
# 59   40789.121052
# 60   44346.428924
# 61   42812.884988
# 62   39452.679546
# 63   41627.293925
# 64   38031.268048

# %%
data_frame.groupby('Age')[['Income']].mean().sort_values(by='Income')
# Out:
#            Income
# Age
# 64   38031.268048
# 34   38843.768895
# 30   39057.861676
# 44   39407.815162
# 62   39452.679546
# 45   39691.743501
# 37   39864.216759
# 27   40031.678842
# 51   40052.275891
# 54   40154.068359
# 58   40199.338098
# 42   40225.185873
# 56   40272.148819
# 25   40433.637275
# 28   40481.137124
# 59   40789.121052
# 32   40846.693940
# 38   40865.678253
# 53   41040.146373
# 19   41119.464152
# 20   41138.458234
# 48   41146.135002
# 41   41219.050511
# 26   41423.269375
# 63   41627.293925
# 43   41643.692710
# 36   41694.219379
# 21   42093.026955
# 52   42125.227164
# 31   42182.054031
# 22   42292.638448
# 50   42468.562003
# 57   42558.509818
# 55   42638.621513
# 18   42693.958699
# 61   42812.884988
# 39   42989.970280
# 49   43335.422431
# 24   43339.961352
# 40   43346.301386
# 35   43417.264831
# 23   43929.269124
# 46   43946.369293
# 29   44014.925164
# 60   44346.428924
# 47   44348.726011
# 33   44528.858202

# %%
data_frame.isnull()
# Out:
#        Income    Age  Dependents  Occupation  City_Tier   Rent  \
# 0       False  False       False       False      False  False
# 1       False  False       False       False      False  False
# 2       False  False       False       False      False  False
# 3       False  False       False       False      False  False
# 4       False  False       False       False      False  False
# ...       ...    ...         ...         ...        ...    ...
# 19995   False  False       False       False      False  False
# 19996   False  False       False       False      False  False
# 19997   False  False       False       False      False  False
# 19998   False  False       False       False      False  False
# 19999   False  False       False       False      False  False
#
#        Loan_Repayment  Insurance  Groceries  Transport  ...  Desired_Savings  \
# 0               False      False      False      False  ...            False
# ...

# %%
data_frame.isna().sum()/len(data_frame)*100
# Out:
# Income                             0.0
# Age                                0.0
# Dependents                         0.0
# Occupation                         0.0
# City_Tier                          0.0
# Rent                               0.0
# Loan_Repayment                     0.0
# Insurance                          0.0
# Groceries                          0.0
# Transport                          0.0
# Eating_Out                         0.0
# Entertainment                      0.0
# Utilities                          0.0
# Healthcare                         0.0
# Education                          0.0
# Miscellaneous                      0.0
# Desired_Savings_Percentage         0.0
# Desired_Savings                    0.0
# Disposable_Income                  0.0
# Potential_Savings_Groceries        0.0
# Potential_Savings_Transport        0.0
# Potential_Savings_Eating_Out       0.0
# Potential_Savings_Entertainment    0.0
# Potential_Savings_Utilities        0.0
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Income                           20000 non-null  float64
#  1   Age                              20000 non-null  int64
#  2   Dependents                       20000 non-null  int64
#  3   Occupation                       20000 non-null  object
#  4   City_Tier                        20000 non-null  object
#  5   Rent                             20000 non-null  float64
#  6   Loan_Repayment                   20000 non-null  float64
#  7   Insurance                        20000 non-null  float64
#  8   Groceries                        20000 non-null  float64
#  9   Transport                        20000 non-null  float64
#  10  Eating_Out                       20000 non-null  float64
# ...

# %%
data_frame.describe().transpose()
# Out:
#                                    count          mean           std  \
# Income                           20000.0  41585.496104  40014.540538
# Age                              20000.0     41.031450     13.578725
# Dependents                       20000.0      1.995950      1.417616
# Rent                             20000.0   9115.494629   9254.228188
# Loan_Repayment                   20000.0   2049.800292   4281.789941
# Insurance                        20000.0   1455.028761   1492.938435
# Groceries                        20000.0   5205.667493   5035.953689
# Transport                        20000.0   2704.466685   2666.345648
# Eating_Out                       20000.0   1461.856982   1481.660811
# Entertainment                    20000.0   1448.853658   1489.019270
# Utilities                        20000.0   2504.976953   2522.981880
# Healthcare                       20000.0   1663.081794   1628.163024
# Education                        20000.0   2498.348422   3098.438166
# ...

# %%
# To expand e scientific notation
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
data_frame.describe().transpose()
# Out:
#                                    count     mean      std      min      25%  \
# Income                          20000.00 41585.50 40014.54  1301.19 17604.88
# Age                             20000.00    41.03    13.58    18.00    29.00
# Dependents                      20000.00     2.00     1.42     0.00     1.00
# Rent                            20000.00  9115.49  9254.23   235.37  3649.42
# Loan_Repayment                  20000.00  2049.80  4281.79     0.00     0.00
# Insurance                       20000.00  1455.03  1492.94    30.00   580.20
# Groceries                       20000.00  5205.67  5035.95   154.08  2165.43
# Transport                       20000.00  2704.47  2666.35    81.23  1124.58
# Eating_Out                      20000.00  1461.86  1481.66    39.44   581.01
# Entertainment                   20000.00  1448.85  1489.02    45.42   581.63
# Utilities                       20000.00  2504.98  2522.98    75.43  1017.67
# ...

# %%
count = data_frame[data_frame['Age'] < 30].shape[0]

# %%
print(f"Number of records where Age < 30: {count}")
# Out:
# Number of records where Age < 30: 5112

# %%
# Drop records where Age >=30
data_frame = data_frame[data_frame['Age'] < 30]

# Save the cleaned dataset
data_frame.to_csv('filtered_data.csv', index=False)

# Download the new file
from google.colab import files
files.download('filtered_data.csv')

# Display the first few rows
data_frame.head()
# Out:
#            Income  Age  Dependents     Occupation City_Tier          Rent  \
# 3   101455.600247   21           0  Self_Employed    Tier_3  15218.340037
# 13    6492.016466   22           3        Retired    Tier_3    973.802470
# 17   38574.647021   21           4   Professional    Tier_2   7714.929404
# 26   11946.071980   19           4        Student    Tier_2   2389.214396
# 35   11296.833460   27           2        Retired    Tier_2   2259.366692
#
#     Loan_Repayment    Insurance     Groceries    Transport  ...  \
# 3      6809.441427  4889.418087  14690.149363  7106.130005  ...
# 13        0.000000   184.243341    955.499426   494.824192  ...
# 17        0.000000  1838.336035   5126.823467  2614.478029  ...
# 26        0.000000   413.296293   1363.786116   641.888253  ...
# 35        0.000000   380.878040   1382.734509   763.560869  ...
#
#     Desired_Savings  Disposable_Income  Potential_Savings_Groceries  \
# ...

# %%
#Importing pandas library
import pandas as pd
#Loading data into a DataFrame
filtered_data=pd.read_csv('/content/drive/MyDrive/SDGP Implementation/filtered_data.csv')

# %%
filtered_data.shape
# Out:
# (5112, 27)

# %%
filtered_data[['Age']].describe()
# Out:
#                Age
# count  5112.000000
# mean     23.445618
# std       3.431553
# min      18.000000
# 25%      21.000000
# 50%      23.000000
# 75%      26.000000
# max      29.000000

# %%
filtered_data.dropna
# Out:
# <bound method DataFrame.dropna of              Income  Age  Dependents     Occupation City_Tier          Rent  \
# 0     101455.600247   21           0  Self_Employed    Tier_3  15218.340037
# 1       6492.016466   22           3        Retired    Tier_3    973.802470
# 2      38574.647021   21           4   Professional    Tier_2   7714.929404
# 3      11946.071980   19           4        Student    Tier_2   2389.214396
# 4      11296.833460   27           2        Retired    Tier_2   2259.366692
# ...             ...  ...         ...            ...       ...           ...
# 5107   64797.755664   29           1        Student    Tier_1  19439.326699
# 5108   45208.132385   22           2        Student    Tier_1  13562.439716
# 5109   14380.461643   26           0  Self_Employed    Tier_2   2876.092329
# 5110   90295.772638   21           1        Student    Tier_2  18059.154528
# 5111  118157.817240   27           2   Professional    Tier_1  35447.345172
#
# ...

# %%
filtered_data.shape
# Out:
# (5112, 27)
